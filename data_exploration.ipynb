# %%
import pandas as pd
import numpy as np
import sklearn
import matplotlib.pyplot as plt

# %%
train_file = "./kaggle/brist1d/train.csv"
test_file = "./kaggle/brist1d/test.csv"

df = pd.read_csv(train_file)
df_test = pd.read_csv(test_file)
# Out:
# /tmp/ipykernel_51620/2161042249.py:4: DtypeWarning: Columns (435,436,437,438,439,440,441,442,443,444,445,446,447,448,449,450,451,452,453,454,455,456,457,458,459,460,461,462,463,464,465,466,467,468,469,470,471,472,473,474,475,476,477,478,479,480,481,482,483,484,485,486,487,488,489,490,491,492,493,494,495,496,497,498,499,500,501,502,503,504,505,506) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(train_file)

# %%
bg_cols = [col for col in df.columns if "bg" in col]

print(df[bg_cols].columns.values)
len(df[bg_cols].columns.values)
# Out:
# ['bg-5:55' 'bg-5:50' 'bg-5:45' 'bg-5:40' 'bg-5:35' 'bg-5:30' 'bg-5:25'
#  'bg-5:20' 'bg-5:15' 'bg-5:10' 'bg-5:05' 'bg-5:00' 'bg-4:55' 'bg-4:50'
#  'bg-4:45' 'bg-4:40' 'bg-4:35' 'bg-4:30' 'bg-4:25' 'bg-4:20' 'bg-4:15'
#  'bg-4:10' 'bg-4:05' 'bg-4:00' 'bg-3:55' 'bg-3:50' 'bg-3:45' 'bg-3:40'
#  'bg-3:35' 'bg-3:30' 'bg-3:25' 'bg-3:20' 'bg-3:15' 'bg-3:10' 'bg-3:05'
#  'bg-3:00' 'bg-2:55' 'bg-2:50' 'bg-2:45' 'bg-2:40' 'bg-2:35' 'bg-2:30'
#  'bg-2:25' 'bg-2:20' 'bg-2:15' 'bg-2:10' 'bg-2:05' 'bg-2:00' 'bg-1:55'
#  'bg-1:50' 'bg-1:45' 'bg-1:40' 'bg-1:35' 'bg-1:30' 'bg-1:25' 'bg-1:20'
#  'bg-1:15' 'bg-1:10' 'bg-1:05' 'bg-1:00' 'bg-0:55' 'bg-0:50' 'bg-0:45'
#  'bg-0:40' 'bg-0:35' 'bg-0:30' 'bg-0:25' 'bg-0:20' 'bg-0:15' 'bg-0:10'
#  'bg-0:05' 'bg-0:00' 'bg+1:00']
# 73

# %%
plt.hist(df[bg_cols[0]])
plt.show()
plt.clf()
plt.hist(df[bg_cols[1]])
plt.show()
plt.clf()
plt.hist(df[bg_cols[2]])
plt.show()
plt.clf()
plt.hist(df[bg_cols[3]])
plt.show()
plt.clf()
